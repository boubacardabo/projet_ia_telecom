# %%
import openllm

# %%
# sync API
# client = openllm.HTTPClient('http://127.0.0.1:8001', timeout=120)
# res = client.generate('What is the weight of the earth?', max_new_tokens=8192)

#Async API
async_client = openllm.AsyncHTTPClient("http://127.0.0.1:8001")
res = await async_client.generate("what is the weight of the earth?", max_new_tokens=128)
print(res.outputs[0].text)
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_backends/anyio.py:34, in AnyIOStream.read(self, max_bytes, timeout)
#      33 try:
# ---> 34     return await self._stream.receive(max_bytes=max_bytes)
#      35 except anyio.EndOfStream:  # pragma: nocover
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py:1203, in SocketStream.receive(self, max_bytes)
#    1202 self._transport.resume_reading()
# -> 1203 await self._protocol.read_event.wait()
#    1204 self._transport.pause_reading()
#
# File ~/anaconda3/lib/python3.11/asyncio/locks.py:213, in Event.wait(self)
#     212 try:
# --> 213     await fut
#     214     return True
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_backends/anyio.py:32, in AnyIOStream.read(self, max_bytes, timeout)
#      31 with map_exceptions(exc_map):
# ---> 32     with anyio.fail_after(timeout):
#      33         try:
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/anyio/_core/_tasks.py:119, in FailAfterContextManager.__exit__(self, exc_type, exc_val, exc_tb)
#     118 if self._cancel_scope.cancel_called:
# --> 119     raise TimeoutError
#     121 return retval
#
# TimeoutError:
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpx/_transports/default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpx/_transports/default.py:366, in AsyncHTTPTransport.handle_async_request(self, request)
#     365 with map_httpcore_exceptions():
# --> 366     resp = await self._pool.handle_async_request(req)
#     368 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:268, in AsyncConnectionPool.handle_async_request(self, request)
#     267         await self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:251, in AsyncConnectionPool.handle_async_request(self, request)
#     250 try:
# --> 251     response = await connection.handle_async_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_async/http11.py:133, in AsyncHTTP11Connection.handle_async_request(self, request)
#     132         await self._response_closed()
# --> 133 raise exc
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_async/http11.py:111, in AsyncHTTP11Connection.handle_async_request(self, request)
#     103 async with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = await self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_async/http11.py:176, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = await self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_async/http11.py:212, in AsyncHTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = await self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_backends/anyio.py:31, in AnyIOStream.read(self, max_bytes, timeout)
#      26 exc_map = {
#      27     TimeoutError: ReadTimeout,
#      28     anyio.BrokenResourceError: ReadError,
#      29     anyio.ClosedResourceError: ReadError,
#      30 }
# ---> 31 with map_exceptions(exc_map):
#      32     with anyio.fail_after(timeout):
#
# File ~/anaconda3/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpcore/_exceptions.py:15, in map_exceptions(map)
#      14     if isinstance(exc, from_exc):
# ---> 15         raise to_exc(exc) from exc
#      16 raise
#
# ReadTimeout:
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# /Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb Cell 2 line 7
#       <a href='vscode-notebook-cell:/Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # sync API
#       <a href='vscode-notebook-cell:/Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> # client = openllm.HTTPClient('http://127.0.0.1:8001', timeout=120)
#       <a href='vscode-notebook-cell:/Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> # res = client.generate('What is the weight of the earth?', max_new_tokens=8192)
#       <a href='vscode-notebook-cell:/Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>
#       <a href='vscode-notebook-cell:/Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> #Async API
#       <a href='vscode-notebook-cell:/Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> async_client = openllm.AsyncHTTPClient("http://127.0.0.1:8001")
# ----> <a href='vscode-notebook-cell:/Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> res = await async_client.generate("what is the weight of the earth?", max_new_tokens=128)
#       <a href='vscode-notebook-cell:/Users/boubacardabo/Desktop/school/projet_ia_telecom/openLLM_langchain_multi_agent/openLLM.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> print(res.outputs[0].text)
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/openllm_client/_http.py:181, in AsyncHTTPClient.generate(self, prompt, llm_config, stop, adapter_name, timeout, verify, **attrs)
#     179 else:
#     180   llm_config = {**_config, **attrs}
# --> 181 return await self._post(
#     182   f'/{self._api_version}/generate',
#     183   response_cls=Response,
#     184   json=dict(prompt=prompt, llm_config=llm_config, stop=stop, adapter_name=adapter_name),
#     185   options={'max_retries': self._max_retries},
#     186 )
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/openllm_client/_shim.py:621, in AsyncClient._post(self, path, response_cls, json, options, stream, stream_cls)
#     619 if options is None:
#     620   options = {}
# --> 621 return await self.request(
#     622   response_cls, RequestOptions(method='POST', url=path, json=json, **options), stream=stream, stream_cls=stream_cls
#     623 )
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/openllm_client/_shim.py:530, in AsyncClient.request(self, response_cls, options, remaining_retries, stream, stream_cls)
#     521 async def request(
#     522   self,
#     523   response_cls: type[Response],
#    (...)
#     528   stream_cls: type[_AsyncStream] | None = None,
#     529 ) -> Response | _AsyncStream:
# --> 530   return await self._request(
#     531     response_cls, options, remaining_retries=remaining_retries, stream=stream, stream_cls=stream_cls
#     532   )
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/openllm_client/_shim.py:547, in AsyncClient._request(self, response_cls, options, remaining_retries, stream, stream_cls)
#     544 request = self._build_request(options)
#     546 try:
# --> 547   response = await self._inner.send(request, auth=self.auth, stream=stream)
#     548   logger.debug('HTTP [%s, %s]: %s [%i]', request.method, request.url, response.status_code, response.reason_phrase)
#     549   response.raise_for_status()
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpx/_client.py:1617, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1609 follow_redirects = (
#    1610     self.follow_redirects
#    1611     if isinstance(follow_redirects, UseClientDefault)
#    1612     else follow_redirects
#    1613 )
#    1615 auth = self._build_request_auth(request, auth)
# -> 1617 response = await self._send_handling_auth(
#    1618     request,
#    1619     auth=auth,
#    1620     follow_redirects=follow_redirects,
#    1621     history=[],
#    1622 )
#    1623 try:
#    1624     if not stream:
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpx/_client.py:1645, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1642 request = await auth_flow.__anext__()
#    1644 while True:
# -> 1645     response = await self._send_handling_redirects(
#    1646         request,
#    1647         follow_redirects=follow_redirects,
#    1648         history=history,
#    1649     )
#    1650     try:
#    1651         try:
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpx/_client.py:1682, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1679 for hook in self._event_hooks["request"]:
#    1680     await hook(request)
# -> 1682 response = await self._send_single_request(request)
#    1683 try:
#    1684     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpx/_client.py:1719, in AsyncClient._send_single_request(self, request)
#    1714     raise RuntimeError(
#    1715         "Attempted to send an sync request with an AsyncClient instance."
#    1716     )
#    1718 with request_context(request=request):
# -> 1719     response = await transport.handle_async_request(request)
#    1721 assert isinstance(response.stream, AsyncByteStream)
#    1722 response.request = request
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpx/_transports/default.py:365, in AsyncHTTPTransport.handle_async_request(self, request)
#     351 assert isinstance(request.stream, AsyncByteStream)
#     353 req = httpcore.Request(
#     354     method=request.method,
#     355     url=httpcore.URL(
#    (...)
#     363     extensions=request.extensions,
#     364 )
# --> 365 with map_httpcore_exceptions():
#     366     resp = await self._pool.handle_async_request(req)
#     368 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/anaconda3/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File ~/Desktop/school/projet_ia_telecom/nxp_venv/lib/python3.11/site-packages/httpx/_transports/default.py:83, in map_httpcore_exceptions()
#      80     raise
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# ReadTimeout:

# %%
# streaming
for it in async_client.generate_stream('What is the weight of the earth?', max_new_tokens=2048, n=2, best_of=2):
  #print(f'index {it.index}: {it.text} (token: {it.token_ids})')
  print(it.text, end="")
